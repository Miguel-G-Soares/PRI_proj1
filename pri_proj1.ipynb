# %% [markdown]
# # Partes comuns

# %%
print("?")
# Out:
# estas aqui?

# %%
print("?")
# Out:
# estas aqui?

# %%
print("olasouomiguel")
# Out:
# olasouomiguel

# %%
print("testing github")

# %%
print("b")
# Out:
# b

# %%
def pepe(s):return True

# %%
print("olasouogustavo")
# Out:
# olá mundo

# %% [markdown]
# # Text processor pipeline and Indexer

# %% [markdown]
# # Key-word extractor

# %% [markdown]
# # Extractive summarizer

# %% [markdown]
# # Generative summarizer

# %% [markdown]
# # Evaluator

# %%
print("olá")

# %% [markdown]
# # test
# # test2
