# %%
print("?")
# Out:
# estas aqui?

# %%
print("?")
# Out:
# estas aqui?

# %%
print("olasouomiguel")
# Out:
# olasouomiguel

# %%
print("testing github")

# %%
print("b")
# Out:
# b

# %%
def pepe(s):return True

# %%
def papa(s):return True
